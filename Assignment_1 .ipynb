# %% [markdown]
# Assingment 5.1: WAP to find max amoung three numbers and input from user. [Try max() function]
#
# Assingment 5.2: WAP to add all numbers divisible by 7 and 9 from 1 to n and n is given by the user.
#
# Assingment 5.3: WAP to add all prime numbers from 1 to n and n is given by the user.

# %%
a=2
b=5
c=7
if a>b:
  if a>c:
    print("A is greatest")
  else: print("C is greatest")
else:
  if b>c:
    print("B is greatest")
  else: print("C is greatest")
max(a,b,c)
# Out:
# C is greatest
# 7

# %%
n=int(input("Enter a no."))
s=0
for i in range(1,n+1):
  if i%7==0 and i%9==0:
    s=s+i
print(s)
# Out:
# Enter a no.100
# 63

# %%
# adding Prime no.s
def isprime(a):
  f=0
  for i in range(2,(a//2)+1):
    if a%i==0:f=1
  return f


n =int(input("Enter a no."))
s=0
for i in range(2,n+1):
  if isprime(i)==0:
    s=s+i

print("Sum of all prime numbers upto",n)
print(s)
# Out:
# Enter a no.100
# Sum of all prime numbers upto 100
# 1060

# %% [markdown]
# Assingment 1.1: WAP to print your name three times

# %%
for i in range(3):
  print("Aatmita")
# Out:
# Aatmita
# Aatmita
# Aatmita

# %% [markdown]
# Assingment 2.1: WAP to add three numbers and print the result.
#
# Assingment 2.2: WAP to concatinate three strings and print the result.

# %%
a=3
b=4
c=5
d=a+b+c
print("sum is",d)
# Out:
# sum is 12

# %%
a=3
b=4
c=5
d=str(a)+str(b)+str(c)
print("concatination is",d)
# Out:
# concatination is 345

# %% [markdown]
# Assingment 4.1: WAP to print the table of 7, 9.
#
# Assingment 4.2: WAP to print the table of n and n is given by user.
#
# Assingment 4.3: WAP to add all the numbers from 1 to n and n is given by user.

# %%
for i in range(1,11):
  print("7 *",i,"=",7*i)
print()
for i in range(1,11):
  print("9 *",i,"=",9*i)
# Out:
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70
#
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# 9 * 10 = 90

# %%
n=int(input("enter a no. "))
for i in range(1,11):
  print(n,"*",i,"=",n*i)
# Out:
# enter a no. 4
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40

# %%
n=int(input("enter a no. "))
s=0
for i in range(1,n+1):
  s=s+i
print("sum of all numbers =",s)
# Out:
# enter a no. 8
# sum of all numbers = 36

# %% [markdown]
# Assingment 6.1: WAP using function that add all odd numbers from 1 to n, n is given by the user.
#
# Assingment 6.2: WAP using function that add all prime numbers from 1 to n, n given by the user

# %%
def isodd(n):
  if n%2==0: return 0
  return 1

def addodd(n):
  s=0
  for i in range(1,n+1):
    if isodd(i)==1:
      s=s+i
  return s

n=int(input("Enter a number "))
print("Sum of all odd numbers upto",n,"is =",addodd(n))
# Out:
# Enter a number 50
# Sum of all odd numbers upto 50 is = 625

# %%
def IsPrime(n):
	for i in range(2, n//2 + 1):
		if n%i==0:
			return 0
	return 1

def addprime(n):
  s=0
  for i in range(2,n+1):
    if IsPrime(i)==1:
      s=s+i
  return s

n=int(input("Enter a number "))
print("Sum of all prime numbers =",addprime(n))
# Out:
# Enter a number 100
# Sum of all prime numbers = 1060

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.name "Aatmita"
# !git config --global user.email "nysadhody2006@gmail.com"
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.name=Aatmita
# user.email=nysadhody2006@gmail.com

# %%
# Out:
# /content/assignments
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/assignments/.git/

# %%
# !mkdir assig
# %cd assig
# !git init
# Out:
# /content/assig
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/assig/.git/

# %%
# !git clone https://github.com/Nysa028/Assignments.git
# Out:
# Cloning into 'Assignments'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# !cp /content/Assignment_1.ipynb /content/Assignments/
# Out:
# cp: cannot stat '/content/Assignment_1.ipynb': No such file or directory
